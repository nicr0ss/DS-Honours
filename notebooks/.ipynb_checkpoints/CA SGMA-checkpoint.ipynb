# %%
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
import contextily as ctx

# %%
SGMA = "../data/GWBasins.shp"

# %%
gdf = gpd.read_file(SGMA)
gdf.set_crs(epsg=3857, inplace=True)
gdf.set_index('OBJECTID', inplace=True)
gdf['Basin_Prefix'] = gdf['Basin_Numb'].str.split('-').str[0].astype(int)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(column='Basin_Prefix', ax=ax, legend=True, categorical=True, alpha=0.6)

ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)

ax.set_title("Basin Map Color-Coded by Prefix Number", fontsize=15)
ax.set_xlabel("Longitude (Web Mercator)")
ax.set_ylabel("Latitude (Web Mercator)")

plt.show()

# %%
gdf
# Out:
#          Basin_Numb Basin_Subb                    Basin_Name  \
# OBJECTID
# 1             6-035      6-035                CRONISE VALLEY
# 2             9-023      9-023              SAN ELIJO VALLEY
# 3             5-031      5-031                   LONG VALLEY
# 4             4-022      4-022                 MALIBU VALLEY
# 5             5-021   5-021.69             SACRAMENTO VALLEY
# ...             ...        ...                           ...
# 511           4-023      4-023                       RAYMOND
# 512           5-041      5-041               EGG LAKE VALLEY
# 513           3-022      3-022              SANTA ANA VALLEY
# 514           4-011   4-011.04  COASTAL PLAIN OF LOS ANGELES
# 515           3-041      3-041                  MORRO VALLEY
#
#                                       Basin_Su_1 Region_Off Date_Recor  \
# OBJECTID
# 1                                 CRONISE VALLEY        SRO        NaT
# 2                               SAN ELIJO VALLEY        SRO        NaT
# 3                                    LONG VALLEY        NRO        NaT
# 4                                  MALIBU VALLEY        SRO 2015-07-06
# 5            SACRAMENTO VALLEY - WYANDOTTE CREEK        NRO 2019-01-04
# ...                                          ...        ...        ...
# 511                                      RAYMOND        SRO 2016-06-27
# 512                              EGG LAKE VALLEY        NRO        NaT
# 513                             SANTA ANA VALLEY       SCRO        NaT
# 514       COASTAL PLAIN OF LOS ANGELES - CENTRAL        SRO 2016-06-27
# 515                                 MORRO VALLEY       SCRO 2015-06-20
#
#           Record_Edi                                           Comments  \
# OBJECTID
# 1               None                                               None
# 2               None                                               None
# 3               None                                               None
# 4         MZimmerman  Adjusted the southern boundary to the county l...
# 5                CBC                                         2018 BBIDS
# ...              ...                                                ...
