# %%
from arcgis.gis import GIS
from arcgis.features import FeatureLayer
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import MonthLocator, DateFormatter
import seaborn as sns
import geopandas as gpd
import contextily as ctx
import numpy as np
from scipy.stats import gaussian_kde
import warnings
import json
import urllib.request
import requests
warnings.filterwarnings("ignore")

# %% [markdown]
# # Looking at what is available in the 1 Day Continuous Average Data
# [Data Available Here](https://data.cnra.ca.gov/dataset/continuous-groundwater-level-measurements/resource/84e02633-00ca-47e8-97ec-c0093313ddcd) \
# 2.8 M Measurements, 344 Stations reporting, All NorCal

# %%
url = "https://data.cnra.ca.gov/api/3/action/datastore_search"
params = {
    "resource_id": "84e02633-00ca-47e8-97ec-c0093313ddcd",
    "limit": 100000,
    "offset": 0
}

station_stats = {}

def process_chunk(records):
    """Update statistics for each station_id based on a chunk of data."""
    global station_stats

    df = pd.DataFrame(records)

    df['date'] = pd.to_datetime(df['MSMT_DATE'])

    for station_id, group in df.groupby('STATION'):
        dates = group['date'].sort_values()

        if station_id not in station_stats:
            station_stats[station_id] = {
                'earliest_date': dates.iloc[0],
                'latest_date': dates.iloc[-1],
                'total_gap': 0,
                'gap_count': 0
            }
        else:
            station_stats[station_id]['earliest_date'] = min(station_stats[station_id]['earliest_date'], dates.iloc[0])
            station_stats[station_id]['latest_date'] = max(station_stats[station_id]['latest_date'], dates.iloc[-1])

        gaps = dates.diff().dt.days[1:]
        station_stats[station_id]['total_gap'] += gaps.sum()
        station_stats[station_id]['gap_count'] += len(gaps)

while True:
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        if data.get('success', False):
            records = data['result']['records']
            if not records:
                break

            process_chunk(records)

            params['offset'] += params['limit']
        else:
            print("API call was unsuccessful.")
            break
    else:
        print(f"Failed to retrieve data. Status code: {response.status_code}")
        break

final_stats = []
for station_id, stats in station_stats.items():
    avg_gap = stats['total_gap'] / stats['gap_count'] if stats['gap_count'] > 0 else None
    final_stats.append({
        'station_id': station_id,
        'earliest_date': stats['earliest_date'],
        'latest_date': stats['latest_date'],
        'average_gap_days': avg_gap
    })

final_stats_df = pd.DataFrame(final_stats)

# %%
final_stats_df['length'] = (final_stats_df.latest_date - final_stats_df.earliest_date).dt.days

# %%
final_stats_df
# Out:
#         station_id earliest_date latest_date  average_gap_days  length
# 0    01N04E36Q001M    2005-04-30  2020-11-04               1.0    5667
# 1    01N04E36Q002M    2005-05-28  2019-07-07               1.0    5153
# 2    01N04E36Q003M    2006-04-29  2019-07-07               1.0    4817
# 3    01N04E36Q004M    2006-04-29  2019-07-07               1.0    4817
# 4    01S04E28F001M    2005-04-29  2019-07-07               1.0    5182
# ..             ...           ...         ...               ...     ...
# 352  48N05E14R001M    2001-07-26  2008-11-23               1.0    2677
# 353  48N05E16P001M    2001-06-30  2013-09-17               1.0    4462
# 354  48N05E25Q001M    2001-08-17  2003-05-15               1.0     636
# 355  48N05E26D001M    2001-09-13  2008-11-24               1.0    2629
# 356  48N05E36A002M    2001-09-02  2003-06-27               1.0     663
#
# [357 rows x 5 columns]

# %%
plt.figure(figsize=(14, 6))

# Histogram
plt.subplot(1, 2, 1)
sns.histplot(final_stats_df['length'], kde=False, bins=25)
plt.title('Histogram of Date Range Lengths')
plt.xlabel('Date Range (days)')
plt.ylabel('Frequency')

# KDE Plot
plt.subplot(1, 2, 2)
sns.kdeplot(final_stats_df['length'], fill=True, clip=(0,None))
plt.title('KDE of Date Range Lengths')
plt.xlabel('Date Range (days)')
plt.ylabel('Density')

# Adjust layout for better appearance
plt.tight_layout()

# Show the plots
plt.show()

# %%
url = "https://data.cnra.ca.gov/api/3/action/datastore_search"
params = {
    "resource_id": "03967113-1556-4100-af2c-b16a4d41b9d0",
    "limit": 100000,
    "offset": 0
}
response = requests.get(url, params=params)
data = response.json()['result']['records']
station_mapping = pd.DataFrame(data)

# %%
station_mapping.head()
# Out:
#    _id        STATION           SITE_CODE  \
# 0    1  01N04E36Q001M  378861N1214818W001
# 1    2  01N04E36Q002M  378849N1214822W001
# 2    3  01N04E36Q003M  378860N1214819W001
# 3    4  01N04E36Q004M  378850N1214820W001
# 4    5  01S04E28F001M  378186N1215443W001
#
#                                               STNAME WELL_NAME   LATITUDE  \
# 0   Middle River Barrier well 2W screen 61-81 ft bgs    MRL-2W  37.886056
# 1   Middle River Barrier well 3W screen 14-34 ft bgs    MRL-3W  37.884861
# 2    Middle River Barrier well 2 screen 10-20 ft bgs    MLNO-2  37.886028
# 3    Middle River Barrier well 1 screen 10-20 ft bgs    MLNO-1  37.885028
# 4  Grant Line Canal Barrier well 2W screen 10-25 ...   GLWL-2W  37.818556
#
#     LONGITUDE LLDATUM      POSACC  ELEV  ...          ELEVACC  COUNTY_NAME  \
# 0 -121.481833   NAD83  Survey, 1m   6.9  ...  R.L. AT SURFACE  San Joaquin
# 1 -121.482167   NAD83  Survey, 1m  -1.0  ...  R.L. AT SURFACE  San Joaquin
# 2 -121.481917   NAD83  Survey, 1m   8.6  ...  R.L. AT SURFACE  San Joaquin
# 3 -121.482000   NAD83  Survey, 1m  15.9  ...  R.L. AT SURFACE  San Joaquin
# 4 -121.544333   NAD83  Survey, 1m  16.1  ...  R.L. AT SURFACE  San Joaquin
#
#   BASIN_CODE BASIN_NAME WELL_DEPTH     WELL_USE    WELL_TYPE WCR_NO  \
# 0   5-022.15      Tracy       81.0  Observation  Single Well   None
# 1   5-022.15      Tracy       34.0  Observation  Single Well   None
# 2   5-022.15      Tracy       20.0  Observation  Single Well   None
# 3   5-022.15      Tracy       20.0  Observation  Single Well   None
# 4   5-022.15      Tracy       25.0  Observation  Single Well   None
#
#                                                  WDL  \
# 0  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 1  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 2  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 3  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 4  https://wdl.water.ca.gov/StationDetails.aspx?S...
#
#                                              COMMENT
# 0  01N04E36Q001M is part of a well cluster.  Othe...
# 1  01N04E36Q002M is part of a well cluster.  Othe...
# 2  01N04E36Q003M is part of a well cluster.  Othe...
# 3  01N04E36Q004M is part of a well cluster.  Othe...
# 4  01S04E28F001M is part of a well cluster.  Othe...
#
# [5 rows x 21 columns]

# %%
stats_locations = final_stats_df.merge(station_mapping, left_on="station_id", right_on="STATION")

# %%
stats_locations.head()
# Out:
#       station_id earliest_date latest_date  average_gap_days  length  _id  \
# 0  01N04E36Q001M    2005-04-30  2020-11-04               1.0    5667    1
# 1  01N04E36Q002M    2005-05-28  2019-07-07               1.0    5153    2
# 2  01N04E36Q003M    2006-04-29  2019-07-07               1.0    4817    3
# 3  01N04E36Q004M    2006-04-29  2019-07-07               1.0    4817    4
# 4  01S04E28F001M    2005-04-29  2019-07-07               1.0    5182    5
#
#          STATION           SITE_CODE  \
# 0  01N04E36Q001M  378861N1214818W001
# 1  01N04E36Q002M  378849N1214822W001
# 2  01N04E36Q003M  378860N1214819W001
# 3  01N04E36Q004M  378850N1214820W001
# 4  01S04E28F001M  378186N1215443W001
#
#                                               STNAME WELL_NAME  ...  \
# 0   Middle River Barrier well 2W screen 61-81 ft bgs    MRL-2W  ...
# 1   Middle River Barrier well 3W screen 14-34 ft bgs    MRL-3W  ...
# 2    Middle River Barrier well 2 screen 10-20 ft bgs    MLNO-2  ...
# 3    Middle River Barrier well 1 screen 10-20 ft bgs    MLNO-1  ...
# 4  Grant Line Canal Barrier well 2W screen 10-25 ...   GLWL-2W  ...
#
#            ELEVACC  COUNTY_NAME BASIN_CODE BASIN_NAME  WELL_DEPTH  \
# 0  R.L. AT SURFACE  San Joaquin   5-022.15      Tracy        81.0
# 1  R.L. AT SURFACE  San Joaquin   5-022.15      Tracy        34.0
# 2  R.L. AT SURFACE  San Joaquin   5-022.15      Tracy        20.0
# 3  R.L. AT SURFACE  San Joaquin   5-022.15      Tracy        20.0
# 4  R.L. AT SURFACE  San Joaquin   5-022.15      Tracy        25.0
#
#       WELL_USE    WELL_TYPE WCR_NO  \
# 0  Observation  Single Well   None
# 1  Observation  Single Well   None
# 2  Observation  Single Well   None
# 3  Observation  Single Well   None
# 4  Observation  Single Well   None
#
#                                                  WDL  \
# 0  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 1  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 2  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 3  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 4  https://wdl.water.ca.gov/StationDetails.aspx?S...
#
#                                              COMMENT
# 0  01N04E36Q001M is part of a well cluster.  Othe...
# 1  01N04E36Q002M is part of a well cluster.  Othe...
# 2  01N04E36Q003M is part of a well cluster.  Othe...
# 3  01N04E36Q004M is part of a well cluster.  Othe...
# 4  01S04E28F001M is part of a well cluster.  Othe...
#
# [5 rows x 26 columns]

# %%
stats_loc_geo = gpd.GeoDataFrame(stats_locations, 
                                geometry=gpd.points_from_xy(stats_locations['LONGITUDE'], stats_locations['LATITUDE']),
                                crs="EPSG:4326")
stats_loc_geo.to_crs(epsg=3857, inplace=True)
today = datetime.today()
stats_loc_geo['days_since_today'] = (today - stats_loc_geo['latest_date']).dt.days

# %%
fig, ax = plt.subplots(figsize=(10, 10))
stats_loc_geo.plot(markersize=5, figsize=(10, 8), color="red", alpha=0.4, ax=ax)
ctx.add_basemap(ax, crs=stats_loc_geo.crs, source=ctx.providers.OpenStreetMap.Mapnik)
plt.title("Heatmap of Points in California (Static)")
plt.show()

# %%
stats_loc_geo['latest_date'] = pd.to_datetime(stats_loc_geo['latest_date'])
buffer_distance = 10 * 1609.34

def calculate_min_days_for_point(point, gdf):
        # Create a buffer around the point
        buffer = point.buffer(buffer_distance)
        # Find neighbors within the buffer
        neighbors = gdf[gdf.geometry.within(buffer)]
        # Return the minimum days since today among neighbors
        return neighbors['days_since_today'].min()

stats_loc_geo['10_mile_min_days'] = stats_loc_geo.apply(lambda row: calculate_min_days_for_point(row.geometry, stats_loc_geo), axis=1)

# %%
stats_loc_geo.head()
# Out:
#       station_id earliest_date latest_date  average_gap_days  length  _id  \
# 0  01N04E36Q001M    2005-04-30  2020-11-04               1.0    5667    1
# 1  01N04E36Q002M    2005-05-28  2019-07-07               1.0    5153    2
# 2  01N04E36Q003M    2006-04-29  2019-07-07               1.0    4817    3
# 3  01N04E36Q004M    2006-04-29  2019-07-07               1.0    4817    4
# 4  01S04E28F001M    2005-04-29  2019-07-07               1.0    5182    5
#
#          STATION           SITE_CODE  \
# 0  01N04E36Q001M  378861N1214818W001
# 1  01N04E36Q002M  378849N1214822W001
# 2  01N04E36Q003M  378860N1214819W001
# 3  01N04E36Q004M  378850N1214820W001
# 4  01S04E28F001M  378186N1215443W001
#
#                                               STNAME WELL_NAME  ...  \
# 0   Middle River Barrier well 2W screen 61-81 ft bgs    MRL-2W  ...
# 1   Middle River Barrier well 3W screen 14-34 ft bgs    MRL-3W  ...
# 2    Middle River Barrier well 2 screen 10-20 ft bgs    MLNO-2  ...
# 3    Middle River Barrier well 1 screen 10-20 ft bgs    MLNO-1  ...
# 4  Grant Line Canal Barrier well 2W screen 10-25 ...   GLWL-2W  ...
#
#    BASIN_NAME  WELL_DEPTH     WELL_USE    WELL_TYPE  WCR_NO  \
# 0       Tracy        81.0  Observation  Single Well    None
# 1       Tracy        34.0  Observation  Single Well    None
# 2       Tracy        20.0  Observation  Single Well    None
# 3       Tracy        20.0  Observation  Single Well    None
# 4       Tracy        25.0  Observation  Single Well    None
#
#                                                  WDL  \
# 0  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 1  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 2  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 3  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 4  https://wdl.water.ca.gov/StationDetails.aspx?S...
#
#                                              COMMENT  \
# 0  01N04E36Q001M is part of a well cluster.  Othe...
# 1  01N04E36Q002M is part of a well cluster.  Othe...
# 2  01N04E36Q003M is part of a well cluster.  Othe...
# 3  01N04E36Q004M is part of a well cluster.  Othe...
# 4  01S04E28F001M is part of a well cluster.  Othe...
#
#                             geometry days_since_today 10_mile_min_days
# 0  POINT (-13523295.827 4563341.766)             1480             1480
# 1  POINT (-13523332.934 4563173.294)             1966             1480
# 2  POINT (-13523305.104 4563337.848)             1966             1480
# 3  POINT (-13523314.381 4563196.802)             1966             1480
# 4  POINT (-13530253.295 4553825.413)             1966             1480
#
# [5 rows x 29 columns]

# %%
norm = plt.Normalize(vmin=stats_loc_geo['10_mile_min_days'].min(), vmax=stats_loc_geo['10_mile_min_days'].max())

fig, ax = plt.subplots(figsize=(10, 10))
stats_loc_geo.plot(column='10_mile_min_days', cmap="viridis", norm=norm, ax=ax, legend=False)  # Disable automatic legend
ctx.add_basemap(ax, crs=stats_loc_geo.crs, source=ctx.providers.OpenStreetMap.Mapnik)
ax.set_title("Heatmap of California with 10-Mile Average 'Days Ago'")

sm = plt.cm.ScalarMappable(cmap="viridis", norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax, orientation='vertical', fraction=0.046, pad=0.04)
cbar.set_label('Average Days Ago')

plt.show()

# %%
stats_loc_geo
# Out:
#         station_id earliest_date latest_date  average_gap_days  length  _id  \
# 0    01N04E36Q001M    2005-04-30  2020-11-04               1.0    5667    1
# 1    01N04E36Q002M    2005-05-28  2019-07-07               1.0    5153    2
# 2    01N04E36Q003M    2006-04-29  2019-07-07               1.0    4817    3
# 3    01N04E36Q004M    2006-04-29  2019-07-07               1.0    4817    4
# 4    01S04E28F001M    2005-04-29  2019-07-07               1.0    5182    5
# ..             ...           ...         ...               ...     ...  ...
# 339  48N05E14R001M    2001-07-26  2008-11-23               1.0    2677  618
# 340  48N05E16P001M    2001-06-30  2013-09-17               1.0    4462  619
# 341  48N05E25Q001M    2001-08-17  2003-05-15               1.0     636  620
# 342  48N05E26D001M    2001-09-13  2008-11-24               1.0    2629  621
# 343  48N05E36A002M    2001-09-02  2003-06-27               1.0     663  622
#
#            STATION           SITE_CODE  \
# 0    01N04E36Q001M  378861N1214818W001
# 1    01N04E36Q002M  378849N1214822W001
# 2    01N04E36Q003M  378860N1214819W001
# 3    01N04E36Q004M  378850N1214820W001
# 4    01S04E28F001M  378186N1215443W001
# ..             ...                 ...
# 339  48N05E14R001M  419963N1213609W001
# 340  48N05E16P001M  419962N1214106W001
# 341  48N05E25Q001M  419657N1213438W001
# 342  48N05E26D001M  419762N1213727W001
# 343  48N05E36A002M  419614N1213411W001
#
#                                                 STNAME             WELL_NAME  \
# 0     Middle River Barrier well 2W screen 61-81 ft bgs                MRL-2W
# 1     Middle River Barrier well 3W screen 14-34 ft bgs                MRL-3W
# 2      Middle River Barrier well 2 screen 10-20 ft bgs                MLNO-2
# 3      Middle River Barrier well 1 screen 10-20 ft bgs                MLNO-1
# 4    Grant Line Canal Barrier well 2W screen 10-25 ...               GLWL-2W
# ..                                                 ...                   ...
# 339        MOD_14R001M screen interval 814 to 1537 bgs   Screen: 814-1537 ft
# 340        MOD_16P001M screen interval 823 to 2108 bgs   Screen: 823-2108 ft
# 341           MOD_25Q001M screen interval 5 to 110 bgs      Screen: 5-110 ft
# 342       MOD_26D001M screen interval 1250 to 1802 bgs  Screen: 1250-1802 ft
# 343         MOD_36A002M screen interval 428 to 528 bgs    Screen: 428-528 ft
#
#      ...  BASIN_NAME  WELL_DEPTH       WELL_USE    WELL_TYPE  WCR_NO  \
# 0    ...       Tracy        81.0    Observation  Single Well    None
# 1    ...       Tracy        34.0    Observation  Single Well    None
# 2    ...       Tracy        20.0    Observation  Single Well    None
# 3    ...       Tracy        20.0    Observation  Single Well    None
# 4    ...       Tracy        25.0    Observation  Single Well    None
# ..   ...         ...         ...            ...          ...     ...
# 339  ...    Tulelake      2030.0     Irrigation  Single Well  751114
# 340  ...    Tulelake      2600.0     Irrigation  Single Well  751113
# 341  ...    Tulelake       110.0  Stockwatering  Single Well    2309
# 342  ...    Tulelake      1810.0     Irrigation  Single Well  751115
# 343  ...    Tulelake       528.0     Irrigation  Single Well  128105
#
#                                                    WDL  \
# 0    https://wdl.water.ca.gov/StationDetails.aspx?S...
# 1    https://wdl.water.ca.gov/StationDetails.aspx?S...
# 2    https://wdl.water.ca.gov/StationDetails.aspx?S...
# 3    https://wdl.water.ca.gov/StationDetails.aspx?S...
# 4    https://wdl.water.ca.gov/StationDetails.aspx?S...
# ..                                                 ...
# 339  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 340  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 341  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 342  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 343  https://wdl.water.ca.gov/StationDetails.aspx?S...
#
#                                                COMMENT  \
# 0    01N04E36Q001M is part of a well cluster.  Othe...
# 1    01N04E36Q002M is part of a well cluster.  Othe...
# 2    01N04E36Q003M is part of a well cluster.  Othe...
# 3    01N04E36Q004M is part of a well cluster.  Othe...
# 4    01S04E28F001M is part of a well cluster.  Othe...
# ..                                                 ...
# 339                                               None
# 340                                               None
# 341                                               None
# 342                                               None
# 343                                               None
#
#                               geometry days_since_today 10_mile_min_days
# 0    POINT (-13523295.827 4563341.766)             1480             1480
# 1    POINT (-13523332.934 4563173.294)             1966             1480
# 2    POINT (-13523305.104 4563337.848)             1966             1480
# 3    POINT (-13523314.381 4563196.802)             1966             1480
# 4    POINT (-13530253.295 4553825.413)             1966             1480
# ..                                 ...              ...              ...
# 339  POINT (-13509826.466 5160418.178)             5844             4085
# 340  POINT (-13515360.937 5160408.142)             4085             4085
# 341  POINT (-13508086.876 5155770.543)             7863             4085
# 342  POINT (-13511143.487 5157410.494)             5843             4085
# 343  POINT (-13507633.806 5155204.493)             7820             4085
#
# [344 rows x 29 columns]
