# %%
import pandas as pd
import requests
import folium
import reverse_geocoder as rg

# %%
stations = pd.read_csv("../data/GNSS_loc.csv")

# %%
stations
# Out:
#         ID       Station Name  Latitude (deg)  Longitude (deg)
# 0     1LSU       Louisiana_St       30.407425       -91.180263  \
# 1     1NSU       Northwestern       31.750801       -93.097605
# 2     1ULM       U_Of_La_At_M       32.529034       -92.075908
# 3     AB02   Nikolski__AK2007       52.970603      -168.854672
# 4     AB06   FalsePass_AK2005       54.885320      -163.423455
# ...    ...                ...             ...              ...
# 1851  ZMP1   Minneapolis_WAAS       44.637463       -93.152087
# 1852  ZNY1    New_York_WAAS_1       40.784329       -73.097167
# 1853  ZOA1          Oakland_1       37.543055      -122.015951
# 1854  ZSE1     Seattle_WAAS_1       47.286993      -122.188373
# 1855  ZTL4     Atlanta_WAAS_4       33.379689       -84.296727
#
#       Ellipsoidal Elevation (m)         X (m)         Y (m)         Z (m)
# 0                      -6.56246 -1.134030e+05 -5.504361e+06  3.209404e+06  \
# ...

# %%
coordinates = list(zip(stations["Latitude (deg)"], stations["Longitude (deg)"]))

# Perform reverse geocoding
results = rg.search(coordinates)

# Extract the state from the results and add it as a new column
stations["State"] = [result["admin1"] for result in results]
# Out:
# Loading formatted geocoded file...

# %%
stations
# Out:
#         ID       Station Name  Latitude (deg)  Longitude (deg)
# 0     1LSU       Louisiana_St       30.407425       -91.180263  \
# 1     1NSU       Northwestern       31.750801       -93.097605
# 2     1ULM       U_Of_La_At_M       32.529034       -92.075908
# 3     AB02   Nikolski__AK2007       52.970603      -168.854672
# 4     AB06   FalsePass_AK2005       54.885320      -163.423455
# ...    ...                ...             ...              ...
# 1851  ZMP1   Minneapolis_WAAS       44.637463       -93.152087
# 1852  ZNY1    New_York_WAAS_1       40.784329       -73.097167
# 1853  ZOA1          Oakland_1       37.543055      -122.015951
# 1854  ZSE1     Seattle_WAAS_1       47.286993      -122.188373
# 1855  ZTL4     Atlanta_WAAS_4       33.379689       -84.296727
#
#       Ellipsoidal Elevation (m)         X (m)         Y (m)         Z (m)
# 0                      -6.56246 -1.134030e+05 -5.504361e+06  3.209404e+06  \
# ...

# %%
california_map = folium.Map(location=[36.7783, -119.4179], zoom_start=7)  # Center on California

# Add markers for each station
for index, row in stations[stations.State == "California"].iterrows():
    folium.Marker(
        location=[row["Latitude (deg)"], row["Longitude (deg)"]],
        popup=f"Station: {row['Station Name']}<br>ID: {row['ID']}<br>Elevation: {row['Ellipsoidal Elevation (m)']} m",
        tooltip=row["Station Name"]
    ).add_to(california_map)

# Display the map
california_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
idaho_map = folium.Map(location=[44.0682, -114.7420], zoom_start=7)  # Center on Idaho

# Add markers for each station
for index, row in stations[stations.State == "Idaho"].iterrows():
    folium.Marker(
        location=[row["Latitude (deg)"], row["Longitude (deg)"]],
        popup=f"Station: {row['Station Name']}<br>ID: {row['ID']}<br>Elevation: {row['Ellipsoidal Elevation (m)']} m",
        tooltip=row["Station Name"]
    ).add_to(idaho_map)

# Display the map
idaho_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
